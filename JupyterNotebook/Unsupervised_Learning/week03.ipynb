# %%
import pandas as pd
import numpy as np

# %%
#문제 1-1
df = pd.read_csv('titanic_train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#문제 1-2
value_cnts = df['Survived'].value_counts()
print(value_cnts)
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#문제 1-3

value_Queenstown = df['Embarked'].value_counts()
print(value_Queenstown,"\n")
numOfQueenstown = value_Queenstown['Q']
print("퀸즈타운에서 탄 사람 수:",numOfQueenstown)
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
#
# 퀸즈타운에서 탄 사람 수: 77

# %%
#문제 1-4

Pclass_List = df['Pclass'].values.tolist()
print(Pclass_List)
# Out:
# [3, 1, 3, 1, 3, 3, 1, 3, 3, 2, 3, 1, 3, 3, 3, 2, 3, 2, 3, 3, 2, 2, 3, 1, 3, 3, 3, 1, 3, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 1, 2, 1, 1, 2, 3, 2, 3, 3, 1, 1, 3, 1, 3, 2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 3, 1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 2, 1, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 1, 1, 3, 1, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 3, 3, 1, 2, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 1, 2, 3, 2, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3, 2, 3, 3, 1, 3, 2, 1, 2, 3, 3, 1, 3, 3, 3, 1, 1, 1, 2, 3, 3, 1, 1, 3, 2, 3, 3, 1, 1, 1, 3, 2, 1, 3, 1, 3, 2, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 2, 3, 1, 1, 2, 3, 3, 1, 3, 1, 1, 1, 3, 3, 3, 2, 3, 1, 1, 1, 2, 1, 1, 1, 2, 3, 2, 3, 2, 2, 1, 1, 3, 3, 2, 2, 3, 1, 3, 2, 3, 1, 3, 1, 1
# ...

# %%
#문제 1-5
drop_df = df.drop('Fare',axis=1)
drop_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket Cabin Embarked
# 0      0         A/5 21171   NaN        S
# 1      0          PC 17599   C85        C
# 2      0  STON/O2. 3101282   NaN        S
# 3      0            113803  C123        S
# 4      0            373450   NaN        S

# %%
#문제 1-6
drop_df = df.drop(labels=range(101,len(df)) ,axis=0)
drop_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 97            98         1       1       Greenfield, Mr. William Bertram
# 98            99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 99           100         0       2                     Kantor, Mr. Sinai
# 100          101         0       3               Petranec, Miss. Matilda
#
#         Sex   Age  SibSp  Parch    Ticket     Fare    Cabin Embarked
# 96     male  71.0      0      0  PC 17754  34.6542       A5        C
# 97     male  23.0      0      1  PC 17759  63.3583  D10 D12        C
# 98   female  34.0      0      1    231919  23.0000      NaN        S
# 99     male  34.0      1      0    244367  26.0000      NaN        S
# 100  female  28.0      0      0    349245   7.8958      NaN        S

# %%
#문제 2
A = np.array([[1,0],[0,-1]])
A = np.transpose(A)
B = np.array([[1,2,1],[2,0,1]])

dot_product = np.dot(A, B)
print('행렬 내적 결과:\n', dot_product)
# Out:
# 행렬 내적 결과:
#  [[ 1  2  1]
#  [-2  0 -1]]

# %%
#문제 3

score = [ 87, 94, 97, 86, 97, 79, 98, 86, 91, 94, 91, 96, 87, 96, 82, 89, 97, 88, 78, 88,
94, 83, 94, 81, 94, 89, 92, 84, 99, 93, 88, 97, 89]

score = np.array(score)

print("최대값 점수:",np.max(score),"번호",np.argmax(score))
print("최소값 점수:",np.min(score),"번호",np.argmin(score))


sort_index = np.argsort(score)
print("가장 높은 점수 3명:",sort_index[:3])
# Out:
# 최대값 점수: 99 번호 28
# 최소값 점수: 78 번호 18
# 가장 높은 점수 3명: [18  5 23]
