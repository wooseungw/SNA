# %% [markdown]
# 1번 [식 3.8]과 같이 표현하시오. 이를 시그마 기호 를 사용하여 나타내시오.

# %% [markdown]
# $a_1^{(1)} = \sum_{i=1}^2  w_{1i}^{(1)}x_i + b_{1}^{(1)}$
#
# $a_2^{(1)} = \sum_{i=1}^2  w_{2i}^{(1)}x_i + b_{2}^{(1)}$
#
# $a_3^{(1)} = \sum_{i=1}^2  w_{3i}^{(1)}x_i + b_{3}^{(1)}$

# %% [markdown]
# 2. [식 3.9]의 오른쪽 항$A^{(1)} = XW^{(1)} + B^{(1)}$에 p.85에 적혀있는 행렬 $X, W^{(1)} , B^{(1)}$ 을 대입하여 행렬
# 곱을 손 계산하시오. 이 계산 결과가 위 1번에서 구한 
# , 
# , 
# 과 같은가?

# %% [markdown]
# $A^{(1)} = (a_1^{(1)}, a_2^{(1)}, a_3^{(1)}) $
# $X = (x_1,x_2)$
# $B^{(1)}=(b_1^{(1)}, b_2^{(1)}, b_3^{(1)})$
# $W^{(1)} = \begin{pmatrix}
#             w_{11}^{(1)}& w_{21}^{(1)}& w_{31}^{(1)} \\
#             w_{12}^{(1)}& w_{22}^{(1)}& w_{32}^{(1)} \\
#             \end{pmatrix}$
#
#
# $XW^{(1)} = (x_1,x_2)\begin{pmatrix}
#             w_{11}^{(1)}& w_{21}^{(1)}& w_{31}^{(1)} \\
#             w_{12}^{(1)}& w_{22}^{(1)}& w_{32}^{(1)} \\
#             \end{pmatrix}  =
#             \begin{pmatrix}
#             x_1 w_{11}^{(1)}+ x_2 w_{12}^{(1)}, & x_1 w_{21}^{(1)}+ x_2 w_{22}^{(1)}, & x_1 w_{31}^{(1)}+ x_2 w_{32}^{(1)}
#             \end{pmatrix} $
#
# $XW^{(1)} + B^{(1)} = (x_1 w_{11}^{(1)}+ x_2 w_{12}^{(1)},  x_1 w_{21}^{(1)}+ x_2 w_{22}^{(1)},  x_1 w_{31}^{(1)}+ x_2 w_{32}^{(1)} ) + (b_1^{(1)}, b_2^{(1)}, b_3^{(1)}) $
#
# $= (x_1 w_{11}^{(1)}+ x_2 w_{12}^{(1)} + b_1^{(1)},  x_1 w_{21}^{(1)}+ x_2 w_{22}^{(1)}+ b_2^{(1)},  x_1 w_{31}^{(1)}+ x_2 w_{32}^{(1)} + b_3^{(1)} ) = (a_1^{(1)},a_2^{(1)},a_3^{(1)})$

# %% [markdown]
# 3. [그림 3-18]에서와 같이, 순전파 시, 은닉층의 모든 노드에서의 연산은, a를 계산하는 단계와 z를 계산하는 단계로 두 단계로 나눈다. a와 z는 각각 무엇을 의미하는가?
#
#
# A: a는 가중신호와 편향의 총합을 나타내고 z는 a가 활성화 함수에 통과한 값입니다.

# %% [markdown]
# 4. $x_1 = 1, x_2 = 2$입력을 순방향으로 전파시킬 때, 1층 두 노드 값은 무엇이 되는가?
# 단, 각 노드의 활성함수는 시그모이드를 사용하며, [식 3.9]와 같이 행렬을 이용한 수식을 적고, 다차원
# 배열을 이용한 파이썬 코드를 작성하여 계산하시오.

# %%
import numpy as np
def sigmoid(h):
    return 1/(1+np.exp(-h))

X = [1,2]
B1 = np.array([1,1])
B2 = np.array([1,-1])
B3 = np.array([-1,1])
W_1 =np.array([[2,-1],[-1,1]])
W_2 = np.array([[0,1],[2,1]])
W_3 = np.array([[1,-2],[2,1]])

Z1 = np.dot(X,W_1) + B1

print(sigmoid(Z1))
# Out:
# [0.73105858 0.88079708]

# %% [markdown]
# 5. $x_1 = 1, x_2 = 2$입력을 순방향으로 전파시킬 때, 2층 두 노드 값은 무엇이 되는가?
# 단, 각 노드의 활성함수는 시그모이드를 사용하며, [식 3.9]와 같이 행렬을 이용한 수식을 적고, 다차원
# 배열을 이용한 파이썬 코드를 작성하여 계산하시오.

# %%
Z2 = np.dot(Z1,W_2)+B2
print(sigmoid(Z2))
# Out:
# [0.99330715 0.88079708]

# %% [markdown]
# 6. $x_1 = 1, x_2 = 2$입력을 순방향으로 전파시킬 때, 출력층 두 노드 값은 무엇이 되는가?
# 단, 각 노드의 활성함수는 시그모이드를 사용하며, [식 3.9]와 같이 행렬을 이용한 수식을 적고, 다차원
# 배열을 이용한 파이썬 코드를 작성하여 계산하시오.

# %%
Z3 = np.dot(Z2,W_2)+B3
print(sigmoid(Z3))
# Out:
# [0.95257413 0.99966465]

# %% [markdown]
# 7. 교재를 참고하여 MNIST 데이터와 신경망 매개변수들을 로드하고, 테스트 데이터에 대해 정확도를
# 구하는 코드를 작성하시오.

# %%
import sys
import os
import pickle
import numpy as np
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
from mnist import load_mnist

def sigmoid(h):
    return 1/(1+np.exp(-h))

def softmax(a):
    c = np.max(a)
    exp_a = np.exp(a - c)  # 오버플로 대책
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a

    return y

def get_data():
    (x_train, t_train), (x_test, t_test) = \
        load_mnist(flatten=True, normalize=True, one_hot_label=False)
    return x_test, t_test


def init_network():
    with open("sample_weight.pkl", 'rb') as f:
        # 학습된 가중치 매개변수가 담긴 파일
        # 학습 없이 바로 추론을 수행
        network = pickle.load(f)

    return network


def predict(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    a1 = np.dot(x, W1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) + b3
    y = softmax(a3)

    return y


x, t = get_data()
network = init_network()
accuracy_cnt = 0

count = np.zeros(10)
_ , all = np.unique(t,return_counts=True)


for i in range(len(x)):
    y = predict(network, x[i])
    p = np.argmax(y)  # 확률이 가장 높은 원소의 인덱스를 얻는다.
    if p == t[i]:
        accuracy_cnt += 1
        count[p] += 1


print("Accuracy:" + str(float(accuracy_cnt) / len(x)))  # Accuracy:0.9352
print("Accuracy(8):", str(float(count[7]/all[7])))
# Out:
# Accuracy:0.9352
# Accuracy(8): 0.9319066147859922

# %% [markdown]
# 9. 에 각각의 정확도를 구해 보시오. 어느 숫자를 가장 잘 인식 못하는가(정확도가 떨어지는가)?

# %%
for i in range(10):
  print("Accuracy of",i+1,"=", str(float(count[i]/all[i])))

print("6 인식율이 가장 낮습니다.")
# Out:
# Accuracy of 1 = 0.9816326530612245
# Accuracy of 2 = 0.9770925110132158
# Accuracy of 3 = 0.9224806201550387
# Accuracy of 4 = 0.9277227722772278
# Accuracy of 5 = 0.9378818737270875
# Accuracy of 6 = 0.8890134529147982
# Accuracy of 7 = 0.9498956158663883
# Accuracy of 8 = 0.9319066147859922
# Accuracy of 9 = 0.9117043121149897
# Accuracy of 10 = 0.9137760158572844
# 6 인식율이 가장 낮습니다.
