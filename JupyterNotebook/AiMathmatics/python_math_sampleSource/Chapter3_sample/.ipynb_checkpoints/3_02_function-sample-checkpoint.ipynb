# %% [markdown]
# ▲리스트3.4: 수학의 함수를 Python 함수로 구현한다

# %%
import numpy as np

def my_func(x):  # my_func라는 이름의 Python 함수로 수식을 구현
    return 3*x + 2  # 3x + 2

x = 4  # 글로벌 변수이므로 위에 적은 인수 x와는 다른 변수
y = my_func(x)  # y = f(x)
print(y)
# Out:
# 14

# %% [markdown]
# #### □문제
# 　리스트3.5의 코드를 보완해서 수식 y=4x+1를 코드로 구현합시다.

# %% [markdown]
# ▲리스트3.5 : 문제

# %%
import numpy as np

def my_func(x):  
    return   # 이 행에서 코드를 보완한다

x = 3
y = my_func(x)  # y = f(x)
print(y)
# Out:
# None

# %% [markdown]
# #### □정답 예

# %% [markdown]
# ▲리스트3.6 : 정답 예

# %%
import numpy as np

def my_func(x):  
    return 4*x + 1  # 4x + 1

x = 3
y = my_func(x)  # y = f(x)
print(y)
# Out:
# 13
