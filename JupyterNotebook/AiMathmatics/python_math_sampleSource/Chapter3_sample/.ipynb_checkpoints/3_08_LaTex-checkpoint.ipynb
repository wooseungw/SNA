# %% [markdown]
# ▲리스트3.29 : 기술 예

# %% [raw]
# $$y=2x+1$$

# %% [markdown]
# $$y=2x+1$$

# %% [markdown]
# ▲리스트3.30 : 정답 예

# %% [raw]
# $$y=x^3 + \sqrt x + \frac{a+{ij}}{b_{ij}^4} - \sum_{k=1}^n a_k$$

# %% [markdown]
# $$y=x^3 + \sqrt x + \frac{a+{ij}}{b_{ij}^4} - \sum_{k=1}^n a_k$$
