# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('lena.jpeg')

cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

opencv_bgr_img = cv2.imread("lena.jpeg")
new_rgb_img = cv2.cvtColor(opencv_bgr_img, cv2.COLOR_BGR2RGB)
out_img = np.hstack((opencv_bgr_img, new_rgb_img))

plt.figure()
plt.title("bgr_rgb_lena")
plt.imshow(out_img)

# %%
import cv2
img = cv2.imread('lena.jpeg')
img = cv2.resize(img,dsize=(0, 0), fx=0.6, fy=0.3, interpolation=cv2. INTER_LINEAR)
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
img = cv2.imread('lena.jpeg')
h, w = img.shape[:2]
s_p = np.float32([[0,0], [w-1,0], [0, h-1]])

img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
d_p = np.float32([[100,0],[w-100,100],[w-400,250]])

transform = cv2.getAffineTransform(s_p, d_p)
img = cv2.warpAffine(img, transform, (img.shape[1], img.shape[0]))
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = cv2.imread('lena.jpeg')

sobel_kernel = np.array([[-1,0,1], [-2,0,2],[-1,0,1]])
sobel_kernel = np.array([[-1,-2,-1],[0,0,0], [1,2,1]])
sobel_gx = cv2.filter2D(img, -1, sobel_kernel)
sobel_gy = cv2.filter2D(img, -1, sobel_kernel)
sobel_x = cv2.Sobel(img, -1, 1, 0, ksize=3)
sobel_y = cv2.Sobel(img, -1, 0, 1, ksize=3)
	
out1 = np.vstack((img, sobel_gx + sobel_gy))
out2 = np.vstack((img, sobel_gx + sobel_y))
out = np.hstack((out1, out2))
cv2.imshow("out", out)
while True:
    if cv2.waitKey(10) == 27:
        break
cv2.destroyAllWindows()

# %%
import cv2
gstr = "nvarguscamerasrc ! video/x-raw(memory:NVMM), width=(int)640, height=(int)480, format=(string)NV12,framerate=(fraction)30/1 ! nvvi dconv flip-method=2 ! video/x-raw, width=(int)640, height=(int)480, format=(string)BGRx !videoconvert ! video/x-raw, format=(string)BGR ! appsink"
cam = cv2.VideoCapture(gstr, cv2.CAP_GSTREAMER)

for i in range(1000):
    _, frame = cam.read()
    cv2.imshow("frame", frame)
    
cam.release()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 7
#       5 for i in range(1000):
#       6     _, frame = cam.read()
# ----> 7     cv2.imshow("frame", frame)
#       9 cam.release()
#
# error: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/highgui/src/window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
